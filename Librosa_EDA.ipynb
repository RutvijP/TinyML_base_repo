# %% [markdown]
# <a href="https://colab.research.google.com/github/RutvijP/TinyML_base_repo/blob/main/Librosa_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display

#import
def plot_audio(audio):
  x, sr = librosa.load(audio)
  X = librosa.stft(x)
  Xdb = librosa.amplitude_to_db(abs(X))
  plt.figure(figsize = (10, 5))
  librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')
  plt.colorbar()

# %%
#function call 
audio = librosa.ex('trumpet')
plot_audio(audio)
